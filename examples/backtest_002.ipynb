# %%
## reload submodule
# %load_ext autoreload
# %autoreload 2

# %%
import pandas as pd

# %%
data = pd.read_csv("./data/_^spx.csv", index_col=0, parse_dates=[0], sep=",")
data

# %%
from qfin.backtester.runners import bt_signal_change

backtest_params = {
    "initial_balance": 10000,
    "default_entry_value": 1,
    "default_entry_value_max": 10000,
    "commission": 0.001,
}

# running a predefined strategy
bt = bt_signal_change(data, **backtest_params)

# %%
stats = bt.stats()
stats
# Out:
# Start                     2023-01-03 00:00:00
# End                       2025-04-07 00:00:00
# Duration                    825 days 00:00:00
# Exposure Time [%]                   96.296296
# Equity Start                            10000
# Equity Peak                             25748
# Equity Final                            25748
# Equity Return [%]                      157.48
# Balance Start                           10000
# Balance Peak                            25748
# Balance Final                           25748
# Balance Return [%]                     157.48
# Gross Return [%]                       159.71
# Total Commissions                         395
# Return (Ann.) [%]                   52.361485
# Volatility (Ann.) [%]               13.497934
# CAGR [%]                            52.001317
# Sharpe Ratio                         3.508795
# Sortino Ratio                        10.48504
# Calmar Ratio                        19.396703
# Max. Drawdown [%]                   -2.699504
# Avg. Drawdown [%]                   -0.662382
# Max. Drawdown Duration       34 days 00:00:00
# Avg. Drawdown Duration        7 days 00:00:00
# Total Trades                               19
# Win Rate [%]                        94.736842
# Best Trade [%]                      27.614228
# Worst Trade [%]                      -2.44859
# Avg. Trade [%]                       8.185924
# Max. Trade Duration         153 days 00:00:00
# Avg. Trade Duration          42 days 00:00:00
# Profit Factor                       66.224009
# Expectancy [%]                       8.405625
# SQN                                  5.081443
# Kelly Criterion                      0.933063
# Candles                                   567
# Long Trades                                 9
# Short Trades                               10
# Exposure Trades [%]                      0.03
# dtype: object

# %%
bt.thumbnail()

# %%
bt.trades()
# Out:
#     is_long leverage  entry_value  entry_price  entry_bar  entry_commission  \
# 0     False     None       9990.0  4179.759766         21              10.0
# 1      True     None       9990.0  3861.590088         46              10.0
# 2     False     None       9990.0  4588.959961        143              10.0
# 3      True     None       9990.0  4117.370117        206              10.0
# 4     False     None       9990.0  5254.350098        310              10.0
# 5      True     None       9990.0  4967.229980        325              10.0
# 6     False     None       9990.0  5667.200195        384              10.0
# 7      True     None       9990.0  5186.330078        398              10.0
# 8     False     None       9990.0  5648.399902        417              10.0
# 9      True     None       9990.0  5408.419922        421              10.0
# 10    False     None       9990.0  6090.270020        485              10.0
# 11     True     None       9990.0  5827.040039        507              10.0
